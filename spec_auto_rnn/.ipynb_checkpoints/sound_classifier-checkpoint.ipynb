# %%
import tensorflow as tf
from tensorflow.python.ops import rnn, rnn_cell
import numpy as np
import os
import librosa
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# # Hyperparameter

# %%
input_size = 499
hidden_layer = 5

sampling_rate = 200
striding = 100
train_steps = 1000

# %%
restorer = tf.train.import_meta_graph('auto.meta')
sess = tf.Session()
restorer.restore(sess, tf.train.latest_checkpoint('./'))
inputs = tf.get_collection("input")
X = inputs[0]
outputs = tf.get_collection("hypo")
H = outputs[0]

# %% [markdown]
# # Average length of different type of sounds
# base 403
# snare 55
# kick 80
# highhat 56

# %% [markdown]
# # Train_set and test_set generator

# %%
train_input_data = []
train_output_data = []
test_input_data = []
test_output_data = []
one_hot = np.eye(4)
for i in range(4):
    train_index = 0.7*nsounds[i]
    for j in range(1,nsounds[i]+1):
        try :
            result = music_loader(i,j)
            y = result['y']
            D = librosa.stft(y,win_length=win_length, hop_length= hop_length)
            D = np.transpose(abs(D))
            if D.shape[0] < train_length:
                continue
                
            if j < train_index:
                train_input_data.append(sess.run(H, feed_dict={X : D[0:train_length]}))
                train_output_data.append(one_hot[i])
            else :
                test_input_data.append(sess.run(H, feed_dict={X : D[0:train_length]}))
                test_output_data.append(one_hot[i])
        except FileNotFoundError:
            print("File not found")
test_input_data = np.array(test_input_data)
test_output_data = np.array(test_output_data)
train_input_data = np.array(train_input_data)
train_output_data = np.array(train_output_data)
# Out:
# /home/maestoj/sound_collection/train/base/base001.wav is loaded
# /home/maestoj/sound_collection/train/base/base002.wav is loaded
# /home/maestoj/sound_collection/train/base/base003.wav is loaded
# /home/maestoj/sound_collection/train/base/base004.wav is loaded
# /home/maestoj/sound_collection/train/base/base005.wav is loaded
# /home/maestoj/sound_collection/train/base/base006.wav is loaded
# /home/maestoj/sound_collection/train/base/base007.wav is loaded
# /home/maestoj/sound_collection/train/base/base008.wav is loaded
# /home/maestoj/sound_collection/train/base/base009.wav is loaded
# /home/maestoj/sound_collection/train/base/base010.wav is loaded
# /home/maestoj/sound_collection/train/base/base011.wav is loaded
# /home/maestoj/sound_collection/train/base/base012.wav is loaded
# /home/maestoj/sound_collection/train/base/base013.wav is loaded
# /home/maestoj/sound_collection/train/base/base014.wav is loaded
# /home/maestoj/sound_collection/train/base/base015.wav is loaded
# /home/maestoj/sound_collection/train/base/base016.wav is loaded
# /home/maestoj/sound_collection/train/base/base017.wav is loaded
# /home/maestoj/sound_collection/train/base/base018.wav is loaded
# /home/maestoj/sound_collection/train/base/base019.wav is loaded
# /home/maestoj/sound_collection/train/base/base020.wav is loaded
# /home/maestoj/sound_collection/train/base/base021.wav is loaded
# /home/maestoj/sound_collection/train/base/base022.wav is loaded
# /home/maestoj/sound_collection/train/base/base023.wav is loaded
# /home/maestoj/sound_collection/train/base/base024.wav is loaded
# /home/maestoj/sound_collection/train/base/base025.wav is loaded
# /home/maestoj/sound_collection/train/base/base026.wav is loaded
# /home/maestoj/sound_collection/train/base/base027.wav is loaded
# /home/maestoj/sound_collection/train/base/base028.wav is loaded
# /home/maestoj/sound_collection/train/base/base029.wav is loaded
# /home/maestoj/sound_collection/train/base/base030.wav is loaded
# /home/maestoj/sound_collection/train/base/base031.wav is loaded
# /home/maestoj/sound_collection/train/base/base032.wav is loaded
# /home/maestoj/sound_collection/train/base/base033.wav is loaded
# /home/maestoj/sound_collection/train/base/base034.wav is loaded
# /home/maestoj/sound_collection/train/base/base035.wav is loaded
# /home/maestoj/sound_collection/train/base/base036.wav is loaded
# /home/maestoj/sound_collection/train/base/base037.wav is loaded
# /home/maestoj/sound_collection/train/base/base038.wav is loaded
# /home/maestoj/sound_collection/train/base/base039.wav is loaded
# /home/maestoj/sound_collection/train/base/base040.wav is loaded
# /home/maestoj/sound_collection/train/base/base041.wav is loaded
# /home/maestoj/sound_collection/train/base/base042.wav is loaded
# /home/maestoj/sound_collection/train/base/base043.wav is loaded
# /home/maestoj/sound_collection/train/base/base044.wav is loaded
# /home/maestoj/sound_collection/train/base/base045.wav is loaded
# /home/maestoj/sound_collection/train/base/base046.wav is loaded
# /home/maestoj/sound_collection/train/base/base047.wav is loaded
# /home/maestoj/sound_collection/train/base/base048.wav is loaded
# /home/maestoj/sound_collection/train/base/base049.wav is loaded
# /home/maestoj/sound_collection/train/base/base050.wav is loaded
# /home/maestoj/sound_collection/train/base/base051.wav is loaded
# /home/maestoj/sound_collection/train/base/base052.wav is loaded
# /home/maestoj/sound_collection/train/base/base053.wav is loaded
# /home/maestoj/sound_collection/train/base/base054.wav is loaded
# /home/maestoj/sound_collection/train/base/base055.wav is loaded
# /home/maestoj/sound_collection/train/base/base056.wav is loaded
# /home/maestoj/sound_collection/train/base/base057.wav is loaded
# /home/maestoj/sound_collection/train/base/base058.wav is loaded
# /home/maestoj/sound_collection/train/base/base059.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare001.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare002.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare003.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare004.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare005.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare006.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare007.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare008.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare009.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare010.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare011.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare012.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare013.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare014.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare015.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare016.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare017.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare018.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare019.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare020.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare021.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare022.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare023.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare024.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare025.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare026.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare027.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare028.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare029.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare030.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare031.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare032.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare033.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare034.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare035.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare036.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare037.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare038.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare039.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare040.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare041.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare042.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare043.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare044.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare045.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare046.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare047.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare048.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare049.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare050.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare051.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare052.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare053.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare054.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare055.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare056.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare057.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare058.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare059.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare060.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare061.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare062.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare063.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare064.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare065.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare066.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare067.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare068.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare069.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare070.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare071.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare072.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare073.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare074.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare075.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare076.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare077.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare078.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare079.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare080.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare081.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare082.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare083.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare084.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare085.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare086.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare087.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare088.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare089.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare090.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare091.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare092.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare093.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare094.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare095.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare096.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare097.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare098.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare099.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare100.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare101.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare102.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare103.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare104.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare105.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare106.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare107.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare108.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare109.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare110.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare111.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare112.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare113.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare114.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare115.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare116.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare117.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare118.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare119.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare120.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare121.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare122.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare123.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare124.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare125.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare126.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare127.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare128.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare129.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare130.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare131.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare132.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare133.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare134.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare135.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare136.wav is loaded
# /home/maestoj/sound_collection/train/snare/snare137.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick001.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick002.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick003.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick004.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick005.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick006.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick007.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick008.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick009.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick010.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick011.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick012.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick013.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick014.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick015.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick016.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick017.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick018.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick019.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick020.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick021.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick022.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick023.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick024.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick025.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick026.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick027.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick028.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick029.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick030.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick031.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick032.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick033.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick034.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick035.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick036.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick037.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick038.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick039.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick040.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick041.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick042.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick043.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick044.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick045.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick046.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick047.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick048.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick049.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick050.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick051.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick052.wav is loaded
# /home/maestoj/sound_collection/train/kick/kick053.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat001.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat002.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat003.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat004.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat005.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat006.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat007.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat008.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat009.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat010.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat011.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat012.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat013.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat014.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat015.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat016.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat017.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat018.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat019.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat020.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat021.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat022.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat023.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat024.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat025.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat026.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat027.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat028.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat029.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat030.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat031.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat032.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat033.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat034.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat035.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat036.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat037.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat038.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat039.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat040.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat041.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat042.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat043.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat044.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat045.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat046.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat047.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat048.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat049.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat050.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat051.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat052.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat053.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat054.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat055.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat056.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat057.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat058.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat059.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat060.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat061.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat062.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat063.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat064.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat065.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat066.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat067.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat068.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat069.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat070.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat071.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat072.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat073.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat074.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat075.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat076.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat077.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat078.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat079.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat080.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat081.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat082.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat083.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat084.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat085.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat086.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat087.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat088.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat089.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat090.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat091.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat092.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat093.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat094.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat095.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat096.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat097.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat098.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat099.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat100.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat101.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat102.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat103.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat104.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat105.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat106.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat107.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat108.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat109.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat110.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat111.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat112.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat113.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat114.wav is loaded
# /home/maestoj/sound_collection/train/hihat/hihat115.wav is loaded

# %%
print("Size of train and test set")
print(train_input_data.shape)
print(train_output_data.shape)
print(test_input_data.shape)
print(test_output_data.shape)
# Out:
# (144, 40, 10)
# (144, 4)
# (62, 40, 10)
# (62, 4)

# %%
x = tf.placeholder('float', [None,train_length,features])
y = tf.placeholder('float', [None,n_classes])

layer = {'weights':tf.Variable(tf.random_normal([rnn_size, n_classes])),
        'biases':tf.Variable(tf.random_normal([n_classes]))}
    
temp_x = tf.transpose(x, [1,0,2])#crucial
temp_x = tf.reshape(temp_x, [-1,features])
temp_x = tf.split(0, train_length, temp_x)

lstm_cell = rnn_cell.LSTMCell(rnn_size)
outputs, states = rnn.rnn(lstm_cell, temp_x, dtype=tf.float32) 

prediction = tf.matmul(outputs[-1],layer['weights']) + layer['biases']

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(prediction,y))
optimizer = tf.train.AdamOptimizer(1e-4).minimize(cost)
correct = tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct, 'float'))
sess.run(tf.global_variables_initializer())

# %%
for step in range(train_steps+1):
    _, c = sess.run([optimizer, cost], feed_dict={x: train_input_data, y: train_output_data})
    if step%200 == 0:
        print("Accuracy : {}".format(sess.run(accuracy, feed_dict={x : test_input_data, y : test_output_data})))
# Out:
# Accuracy : 0.8548387289047241
# Accuracy : 0.8870967626571655
# Accuracy : 0.8870967626571655
# Accuracy : 0.8870967626571655
# Accuracy : 0.8709677457809448
# Accuracy : 0.8548387289047241
# Accuracy : 0.8548387289047241
